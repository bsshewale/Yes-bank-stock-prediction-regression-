# %% [markdown]
# <a href="https://colab.research.google.com/github/bsshewale/Yes-bank-stock-prediction-regression-/blob/main/Yes_bank_stock_prediction_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Regression
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**  - Bharat Santosh Shewale

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The stock price is not only going to increasing it may increase or
# may be fall down so, doing research on stock pricing over some period
# gives some insights or some patterns, which can be apply in future to make profit.
# Yes Bank operates in Retail, MSME and Corporate banking sectors. It offers wide range of differentiated products for corporate and retail customers through retail banking and asset management services.
# The bank's management, under the new leadership of Kumar, immediately repositioned itself and dealt with all internal and market related challenges to restore customer and depositor confidence.
# One of the biggest reasons why people seem to invest in stocks is the possibility of making quick money and not having to work ever again.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **To predict the Stock's closing price of the month**

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Assignments/Project 2/data_YesBank_StockPrices.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#         Date   Open   High    Low  Close Month    OHL
# 0 2005-07-01  13.00  14.00  11.25  12.46   Jul  12.75
# 1 2005-08-01  12.58  14.88  12.55  13.42   Aug  13.34
# 2 2005-09-01  13.48  14.87  12.27  13.30   Sep  13.54
# 3 2005-10-01  13.20  14.47  12.40  12.99   Oct  13.36
# 4 2005-11-01  13.35  13.88  12.88  13.41   Nov  13.37

# %%
df['Date'] = df['Date'].apply(lambda x: datetime.strptime(x, "%b-%y"))

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (185, 5)

# %% [markdown]
# * **Dataset is having 185 rows and 5 columns**

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    datetime64[ns]
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 7.4 KB

# %% [markdown]
# * **As we are seeing that there are total 5 columns and every column is not having any null value**

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().value_counts()
# Out:
# False    185
# dtype: int64

# %% [markdown]
# * **No duplicated values**

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isna().value_counts()
# Out:
# Date   Open   High   Low    Close
# False  False  False  False  False    185
# dtype: int64

# %% [markdown]
# * **No na value**

# %%
# Visualizing the missing values
df.isna().value_counts().plot()
# Out:
# <Axes: xlabel='Date,Open,High,Low,Close'>

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * **They have given data of 185 days in the format of day open, day close, day high and day low.**
# * **Dataset have 185 rows and 5 columns**
# * **Dataset doesn't have any na or missing value**

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close'], dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#              Open        High         Low       Close
# count  185.000000  185.000000  185.000000  185.000000
# mean   105.541405  116.104324   94.947838  105.204703
# std     98.879850  106.333497   91.219415   98.583153
# min     10.000000   11.240000    5.550000    9.980000
# 25%     33.800000   36.140000   28.510000   33.450000
# 50%     62.980000   72.550000   58.000000   62.540000
# 75%    153.000000  169.190000  138.350000  153.300000
# max    369.950000  404.000000  345.500000  367.900000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# There are 5 variables namely
# * Date: Date on which recorded
# * Open: Opening price of the day
# * High: Highest price of the day
# * Low: Lowest price of the day
# * Close: Closing price of the day

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print('Unique values in Open is:',len(df['Open'].unique()))
print('Unique values in Close is:',len(df['Close'].unique()))
print('Unique values in High is:',len(df['High'].unique()))
print('Unique values in Low is:',len(df['Low'].unique()))
# Out:
# Unique values in Open is: 183
# Unique values in Close is: 185
# Unique values in High is: 184
# Unique values in Low is: 183

# %% [markdown]
# * **All the variable are having unique values in majority.**

# %% [markdown]
# ### **Data wrangling, Visualization and EDA**

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
df.plot()
plt.title('Overall rate of stock price over the year')
plt.xlabel('Number of days')
plt.ylabel('Price of the stock')
plt.xlim(0,190)
# Out:
# (0.0, 190.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Line chart will be best to visualize change in price over the year

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Stock price ranges between approximately 10 at the begining and increases slowly over the days and riched to 400 in 150 days after that trend is changed and goes down.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * This can give overall trend of stock price, this chart gives where is the negative trend started and where positive so that we can look into that period for the insight

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Dependent variable 'Closing price'
plt.figure(figsize=(15,10))
sns.displot(df['Close'],color="g")
plt.title('Closing Distribution')
plt.xlabel('Closing Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This give distribution of the closing price vs count of the days.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Max days shows closing price below 50.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * The closing price of the stock is high in very less days.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Dependent variable 'Closing price'
plt.figure(figsize=(15,10))
sns.distplot(df['Close'],color="y")
plt.title('Close Data Distribution')
plt.xlabel('Closing Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze the closing price

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As Closing price increases the density of buyer decreases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This give trend of buyer based on closing price

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 4 visualization code
# Check for skewness in the dataset
numeric_features = df.describe().columns
for col in numeric_features[0:4]:
    fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    feature = df[col]
    feature.hist(bins=50, ax = ax)
    ax.axvline(feature.mean(), color='magenta', linestyle='dashed', linewidth=2)
    ax.axvline(feature.median(), color='cyan', linestyle='dashed', linewidth=2)
    ax.set_title(col)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check the skewness in data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Every variable is positively skewed

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive skewness of all the variables shows trend of buyer.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# scatter plot to see the relationship between dependent & independent variables
for col in df.describe().columns[:-1]:
  fig = plt.figure(figsize=(20,5))
  ax = fig.gca()
  plt.scatter(df[col], df['Close'])
  plt.xlabel(col)
  plt.ylabel('Close')
  ax.set_title('{} vs Close'.format(col))
  z = np.polyfit(df[col], df['Close'], 1)
  y_hat = np.poly1d(z)(df[col])
  plt.plot(df[col], y_hat, "r--", lw=1)
  plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Gives relation between dependent and independent variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Gives scattering datapoints whether there any outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Comparing some variable with each other give few outliers.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Creating a new feature based on average of other features in the dataset
df['OHL'] =df[['Open', 'High', 'Low']].mean(axis=1).round(2)

# scatter plot to see the relationship between dependent & independent variables
fig = plt.figure(figsize=(20,5))
ax = fig.gca()
plt.scatter(df['OHL'], df['Close'])
plt.xlabel('OHL')
plt.ylabel('Close')
ax.set_title('OHL vs Close')
z = np.polyfit(df['OHL'], df['Close'], 1)
y_hat = np.poly1d(z)(df['OHL'])
plt.plot(df['OHL'], y_hat, "r--", lw=1)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Relationship between dependent & independent variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Dependent variables and independent variables are linearly relation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Less outliers.

# %% [markdown]
# #### Chart - 7 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr())
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To observe relation of the variable with each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Dark color shows no correlations while faint one show highest correlation.

# %% [markdown]
# #### Chart - 8 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To pair the variables with each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The variable Low and close shows a great pair also open with high is also a better pair.

# %% [markdown]
# ## ***5. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ##Feature Manipulation & Selection

# %% [markdown]
# ### **1. Feature Manipulation**

# %%
# Manipulate Features to minimize feature correlation and create new features
# Creating a new feature based on average of other features in the dataset
df['OHL'] = df[['Open', 'High', 'Low']].mean(axis=1).round(2)
df.head()
# Out:
#         Date   Open   High    Low  Close    OHL  lag_1  lag_2  lag_3  lag_4  \
# 0 2005-07-01  13.00  14.00  11.25  12.46  12.75    NaN    NaN    NaN    NaN
# 1 2005-08-01  12.58  14.88  12.55  13.42  13.34  12.75    NaN    NaN    NaN
# 2 2005-09-01  13.48  14.87  12.27  13.30  13.54  13.34  12.75    NaN    NaN
# 3 2005-10-01  13.20  14.47  12.40  12.99  13.36  13.54  13.34  12.75    NaN
# 4 2005-11-01  13.35  13.88  12.88  13.41  13.37  13.36  13.54  13.34  12.75
#
#    lag_5  lag_6  lag_7  lag_8  lag_9  lag_10  lag_11  lag_12
# 0    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 1    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 2    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 3    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 4    NaN    NaN    NaN    NaN    NaN     NaN     NaN     NaN

# %% [markdown]
# #### **2. Feature Selection**

# %%
# Select your features wisely to avoid overfitting
# scatter plot to see the relationship between dependent & independent variables
fig = plt.figure(figsize=(20,5))
ax = fig.gca()
plt.scatter(df['OHL'], df['Close'])
plt.xlabel('OHL')
plt.ylabel('Close')
ax.set_title('OHL vs Close')
z = np.polyfit(df['OHL'], df['Close'], 1)
y_hat = np.poly1d(z)(df['OHL'])
plt.plot(df['OHL'], y_hat, "r--", lw=1)
plt.show()

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# I have used scatterplot to select the feature because it give clear indication of fit.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Depending on all variable ohl is important feature.

# %% [markdown]
# ### Splitting Dataset

# %%
# Important import
# importing the required libraries
import warnings                                        # do not disturb mode
warnings.filterwarnings('ignore')                                  # data manipulations
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn-white')
import plotly.express as px

from datetime import datetime                          # to convert to date
from statsmodels.tsa.arima_model import ARIMA          # to build ARIMA


from dateutil.relativedelta import relativedelta       # working with dates with style
from datetime import datetime                          # computational cost
from scipy.optimize import minimize                    # for function minimization
import copy                                            # create copies

from sklearn.preprocessing import (MinMaxScaler,       # scale the data
StandardScaler)
from sklearn.model_selection import train_test_split   # split train and test data
from sklearn.model_selection import (cross_val_score,  # split train and test data on a timeseries
TimeSeriesSplit)

from sklearn.linear_model import LinearRegression      # regression model
from xgboost import XGBRegressor                       # xgboost model
from sklearn.ensemble import RandomForestRegressor     # random forest model
from sklearn.svm import SVR                            # support vector regressor
from sklearn.linear_model import (Lasso, Ridge,        # regularization
ElasticNet, LassoCV, RidgeCV, ElasticNetCV)
from sklearn.model_selection import GridSearchCV       # grid search to optimize parameters

from sklearn.metrics import (r2_score,                 # import required metrics
mean_squared_error,  mean_absolute_percentage_error,
mean_absolute_error)

from statsmodels.tsa.stattools import adfuller         # statistics and econometrics
import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs

# %%
# 5 fold time-series cross-validation
tscv = TimeSeriesSplit(n_splits=5)

# %% [markdown]
# ## **Train test split**

# %%
# function for splitting time-series dataset
def timeseries_train_test_split(X, y, test_size):
    """
        Perform train-test split with respect to time series structure
    """

    # get the index after which test set starts
    test_index = int(len(X)*(1-test_size))
    scaler = StandardScaler()
    X_train = X.iloc[:test_index]
    y_train = y.iloc[:test_index]
    X_test = X.iloc[test_index:]
    y_test = y.iloc[test_index:]

    return X_train, X_test, y_train, y_test

# %%
# choose appropriate dependent and independent variables
y = df.dropna().Close
X = df.dropna().drop(['Date','Close','Open','High','Low'], axis=1)

# split the dataset into train and test sets
X_train, X_test, y_train, y_test = timeseries_train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %% [markdown]
# ##Implementing ridge regression model

# %%
# initialize and fit linear regression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# use lags as additional features
for i in range(1, 13):
    df["lag_{}".format(i)] = df.OHL.shift(i)

# %%
# function to plot model performance
def plotModelResults(model, X_train=X_train, X_test=X_test, plot_intervals=False, plot_anomalies=False):
    """
        Plots modelled vs fact values, prediction intervals and anomalies

    """

    prediction = model.predict(X_test)

    plt.figure(figsize=(15, 7))
    plt.plot(prediction, "g", label="prediction", linewidth=2.0)
    plt.plot(y_test.values, label="actual", linewidth=2.0)

    if plot_intervals:
        cv = cross_val_score(model, X_train, y_train,
                                    cv=tscv,
                                    scoring="neg_mean_absolute_error")
        mae = cv.mean() * (-1)
        deviation = cv.std()
        scale = 1.96
        lower = prediction - (mae + scale * deviation)
        upper = prediction + (mae + scale * deviation)

        plt.plot(lower, "r--", label="upper bond / lower bond", alpha=0.5)
        plt.plot(upper, "r--", alpha=0.5)

        if plot_anomalies:
            anomalies = np.array([np.NaN]*len(y_test))
            anomalies['y_testupper'] = y_test[y_test>upper]
            plt.plot(anomalies, "o", markersize=10, label = "Anomalies")

    error = mean_absolute_percentage_error(prediction, y_test)
    plt.title("Mean absolute percentage error {0:.2f}".format(error))
    plt.legend(loc="best")
    plt.tight_layout()
    plt.grid(True);

# function to plot coefficients
def plotCoefficients(model):
    """
        Plots sorted coefficient values of the model
    """
    coefs = pd.DataFrame(model.coef_, X_train.columns)
    coefs.columns = ["coef"]
    coefs["abs"] = coefs.coef.apply(np.abs)
    coefs = coefs.sort_values(by="abs", ascending=False).drop(["abs"], axis=1)

    plt.figure(figsize=(15, 7))
    coefs.coef.plot(kind='bar')
    plt.grid(True, axis='y')
    plt.hlines(y=0, xmin=0, xmax=len(coefs), linestyles='dashed')

plotModelResults(lr, plot_intervals=True)
plotCoefficients(lr)

# %% [markdown]
# ### **Prediction**

# %%
# make predictions
lr_y_pred = lr.predict(X_test)

# evaluate predictions
lr_mae = round(mean_absolute_error(y_test, lr_y_pred),2)
print('mean absolute error: {}\n'.format(lr_mae))
lr_mse = round(mean_squared_error(y_test, lr_y_pred),2)
print('mean squared error: {}\n'.format(lr_mse))
lr_rmse = round(np.sqrt(lr_mse),2)
print('root mean squared error: {}\n'.format(lr_rmse))
lr_r2 = round(r2_score(y_test, lr_y_pred),2)
print('r2_score: {}\n'.format(lr_r2))
lr_mape = round(mean_absolute_percentage_error(lr_y_pred, y_test),2)
print('mean absolute percentage error: {}\n\n\n'.format(lr_mape))

# Check for homoscadacity
plt.scatter(lr_y_pred, y_test)
plt.title('Variance of residuals')
plt.show()
# Out:
# mean absolute error: 16.93
#
# mean squared error: 486.35
#
# root mean squared error: 22.05
#
# r2_score: 0.97
#
# mean absolute percentage error: 0.19

# %% [markdown]
# ### **Time Series Analysis**
# Moving Average
# A moving average much better than a naive forecast. A moving average is the average of previous values.

# %%
# function for calculating moving average

def moving_average(series, n):

  """
  Calculate average of last n observation
  """

  return round(np.average(series[-n:]),2)

moving_average(df['Close'],12) # prediction for next month closing price using observed previous 12 months data
# Out:
# 24.18

# %% [markdown]
# Unfortunately we can make only one prediction, to make further predictions we need to have the actual observed values. However moving average can be used to identify the trends by smoothing the time series using a pandas implementation DataFrame.rolling(window).mean().

# %%
# # set back up the date column
# df = df.reset_index()
# df['Date'] = df_date

# function for plotting moving average
def ma(series, window, plot_intervals=False):

  """
  series - dataframe column with timeseries
  window - rolling window size
  """

  rolling_mean = series.rolling(window=window).mean()

  plt.figure(figsize=(20,5))
  plt.title('Moving average \n window size = {}'.format(window))
  plt.plot(df['Date'], rolling_mean, "g", label = "Rolling mean trend")

  # plotting confidence intervals
  if plot_intervals:
    mae = mean_absolute_error(series[window:], rolling_mean[window:])
    deviation = np.std(series[window] - rolling_mean[window:])
    lower_bound = rolling_mean - (mae + deviation)
    upper_bound = rolling_mean + (mae + deviation)
    plt.plot(df['Date'], lower_bound, "r--", label = "Upper/Lower bounds")
    plt.plot(df['Date'], upper_bound, "r--")

  plt.plot(df['Date'], series, label = "Actual values")
  plt.legend(loc="upper left")
  plt.grid(True)
  plt.show()

# %%
# plotting 12 months moving average
ma(df['Close'],12, plot_intervals=True) # smoothing by previous 12 months

# %% [markdown]
# ## **Prophet Implementation**

# %%
# set data to train and test
dfp = df[['Date','Close']][175:]
split_date = '2020-05-01'
df_train = dfp.loc[dfp['Date'] <= split_date].copy()
df_test = dfp.loc[dfp['Date'] > split_date].copy()

# %%
# rename columns appropriately
df_train = df_train.rename(columns={'Date':'ds','Close':'y'})
df_test = df_test.rename(columns={'Date':'ds','Close':'y'})

# select appropriate columns
df_test = df_test.drop(columns=['y'], axis=1)
df_test.reset_index(inplace=True)
df_test.drop(columns=['index'], axis=1, inplace=True)

# %%
# Setup and fit the model
from prophet import Prophet
m = Prophet()
m.fit(df_train)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 2.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpktz5ze7u/pwma9m_6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpktz5ze7u/oosu8xmz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68640', 'data', 'file=/tmp/tmpktz5ze7u/pwma9m_6.json', 'init=/tmp/tmpktz5ze7u/oosu8xmz.json', 'output', 'file=/tmp/tmpktz5ze7u/prophet_modelunmf05fh/prophet_model-20230715121013.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 12:10:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 12:10:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# predicted closing prices
forecast = m.predict(df_test)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
#           ds       yhat  yhat_lower  yhat_upper
# 0 2020-06-01  23.611262   18.351448   28.341590
# 1 2020-07-01  21.905517   16.921960   26.963703
# 2 2020-08-01  20.142914   15.294500   24.846893
# 3 2020-09-01  18.380311   13.751272   23.420640
# 4 2020-10-01  16.674566   11.630844   21.391453
# 5 2020-11-01  14.911963   10.024367   20.312507

# %%
# actual closing prices
df[179:][['Date','Close']]
# Out:
#           Date  Close
# 179 2020-06-01  25.60
# 180 2020-07-01  11.95
# 181 2020-08-01  14.37
# 182 2020-09-01  13.15
# 183 2020-10-01  12.42
# 184 2020-11-01  14.67

# %%
y_test = df[179:]['Close']
p_y_pred = forecast['yhat']

# %%
# Plot the forecast
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
fig = m.plot(forecast,
                 ax=ax)
plt.show()

# Plot the components of the model
fig = m.plot_components(forecast)

# %%
# evaluate predictions
p_mae = round(mean_absolute_error(y_test, p_y_pred),2)
print('mean absolute error: {}\n'.format(p_mae))
p_mse = round(mean_squared_error(y_test, p_y_pred),2)
print('mean squared error: {}\n'.format(p_mse))
p_rmse = round(np.sqrt(p_mse),2)
print('root mean squared error: {}\n'.format(p_rmse))
p_r2 = round(r2_score(y_test, p_y_pred),2)
print('r2_score: {}\n'.format(p_r2))
p_mape = round(mean_absolute_percentage_error(p_y_pred, y_test),2)
# Out:
# mean absolute error: 4.57
#
# mean squared error: 30.32
#
# root mean squared error: 5.51
#
# r2_score: -0.38

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * we started with data inspection, viewed the data distribution, checked for correlation and used averaged features to remove correlation.
# * A simple linear regression model was built and it was evaluated using accuracy, mean squared error, root mean squared error, r2_score and mean absolute percentage error.
# * Additional features were engineered by taking lags and reduced the effect of multi collinearity using regularization techniques such as ridge, lasso and elastic net regression.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
